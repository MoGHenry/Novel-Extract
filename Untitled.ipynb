# %%
import requests
import unicodedata
from bs4 import BeautifulSoup, NavigableString
from fake_useragent import UserAgent
import time
import random


def convert_fullwidth_to_halfwidth(text):
    return unicodedata.normalize('NFKC', text)


def get_page_info(url):
    try:
        # Send a request to the URL
        headers = {'User-Agent': UserAgent().random}
        # headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)
        # Chrome/122.0.0.0 Safari/537.36'}
        response = requests.get(url, headers=headers)
        response.raise_for_status()

        # Set response encoding if needed (sometimes needed for correct character display)
        response.encoding = response.apparent_encoding

        # Parse the content of the request with BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        return soup

    except requests.RequestException as e:
        print(f"Error: {e}")
        return None


def extract_novel_info(li_elements):
    novel_info = []

    for element in li_elements:
        # Extract text and add to the list
        a_tag = element.find('a')

        # Check if a_tag is not None
        if a_tag:
            title = element.get_text(strip=True)
            href = a_tag['href']
            if title and href and href != "#":
                novel_info.append({"title": convert_fullwidth_to_halfwidth(title), "href": href})

    return novel_info


def cleanup(html_content):
    if html_content is None:
        return ""
    # Extract text and remove unnecessary whitespace
    return html_content.get_text(separator='\n').strip()


def remove_before_second_occurrence(text, substring):
    # Find the first occurrence of the substring
    first_occurrence = text.find(substring)
    if first_occurrence == -1:
        return text

    second_occurrence = text.find(substring, first_occurrence + 1)
    if second_occurrence == -1:
        return text[first_occurrence:]

    # Return the text from the second occurrence onwards
    return text[second_occurrence:]


def extract_content(novel_info):
    novel_content = []
    i = 0
    for info in novel_info:
        novel_url = info["href"]
        soup = get_page_info(novel_url)

        text = soup.find(class_="txtnav")
        text = cleanup(text)
        text = remove_before_second_occurrence(text, "\u2003\u2003")
        text = text.replace("\u2003\u2003", "")
        text = text.replace("\n\n", "\n")

        novel_content.append({"title": info["title"], "content": text})
        i = i+1
        print(info["title"], f"---({i}/{len(novel_info)})finished")
        sleep_time = random.uniform(0.5, 1.5)
        time.sleep(sleep_time)
    return novel_content


def generate_txt(filename, novel_content):
    with open(filename+".txt", "a", encoding='utf-8') as file:
        for i in novel_content:
            file.write(i["title"]+"\n")
            file.write(i["content"]+"\n")

# %%
url = 'https://www.69shu.pro/book/53686/'
filename = "只想让玩家省钱的我却被氪成首富"
soup = get_page_info(url)
print("get page info successful")
lists = soup.find_all("li")
novel_infos = extract_novel_info(lists)
print("get novel info successful")
# Out:
# get page info successful
# get novel info successful

# %%
novel_infos

# %%
novel_contents = extract_content(novel_infos)
print("get page content successful")
generate_txt(filename, novel_contents)
print("generate txt successful")

# %%
urls = 'https://www.69shu.pro/txt/53686/34787587'
soup = get_page_info(urls)
soup
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport">
# <title>只想让玩家省钱的我却被氪成首富-第43章 游戏首周流水出炉！-69书吧</title>
# <meta content="正文 第43章 游戏首周流水出炉！,只想让玩家省钱的我却被氪成首富最新章节,只想让玩家省钱的我却被氪成首富在线阅读" name="keywords"/>
# <meta content="只想让玩家省钱的我却被氪成首富最新章节无错/无弹窗广告阅读" name="description"/>
# <link href="https://www.69shu.pro/txt/53686/34787588" rel="prefetch"/>
# <link href="https://cdn.shucdn.com/css/yuedu.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.shucdn.com/favicon.ico" rel="shortcut icon">
# <meta content="all" name="robots"/> <script src="https://cdn.shucdn.com/js/202403/ad.js"></script>
# <script>
#         var bookinfo = {
#             pageType: 3,
#             pageVer: '202308002',
#             siteName: '69书吧',
#             site: 'https://www.69shu.pro',
#             articleid: '53686',
#             chapterid: '34787587',
#             articlename: '只想让玩家省钱的我却被氪成首富',
#             chaptername: '第43章 游戏首周流水出炉！',
#             index_page: '/book/53686/',
#             sortName: '官场职场',
#             sortUrl: 'https://www.69shu.pro/novels/class/10.htm',
#             author: '沉唐枕月',
#             preview_page: "https://www.69shu.pro/txt/53686/34787586",
#             next_page: "https://www.69shu.pro/txt/53686/34787588"
#         };
#     </script>
# </link></meta></head>
# <body>
# <div id="pageheadermenu">
# <header></header>
# </div>
# <div class="container">
# <div class="mybox">
# <div class="yueduad1">
# <script>loadAdv(1, 1);</script>
# </div>
# <h3 class="mytitle hide720">
# <div class="bread">
# <a href="https://www.69shu.pro/?t=20231208">首页</a> &gt; 官场职场&gt; <a href="https://www.69shu.pro/book/53686.htm">只想让玩家省钱的我却被氪成首富</a> &gt; 第43章 游戏首周流水出炉！
#             </div>
# </h3>
# <div class="tools">
# <ul>
# <li><a href="https://www.69shu.pro/book/53686.htm"><span>书页</span></a></li>
# <li><span><a href="javascript:;" id="a_addbookcase" onclick="addbookcase(53686,34787587);" rel="nofollow">收藏</a>
# <li><a href="https://www.69shu.pro/book/53686/"><i class="iconfont icon-mulu"></i><span>目录</span></a></li>
# <li><a class="setboxbtn" href="javascript:;"><i class="iconfont icon-setting"></i><span>设置</span></a></li>
# <li><a href="javascript:;" onclick="setbg(setbg)"><i class="iconfont icon-moon"></i><span class="bgtxt">白天</span></a></li>
# </span></li></ul>
# </div>
# <div class="txtnav">
# <h1 class="hide720">第43章 游戏首周流水出炉！</h1>
# <div class="txtinfo hide720"><span>2023-09-26</span> <span>作者： 沉唐枕月</span></div>
# <div id="txtright">
# <script>loadAdv(2, 0);</script>
# </div>
#               第43章 游戏首周流水出炉！
# <br/><br/>
#   氪佬们最开始想的办法，是想找一个比较高明的黑客，入侵一下头号玩家公司的后台端口，然后改写充值界面的程序，直接从根源解决问题。
# <br/><br/>
#   不过由于这种行为已经足够触碰到违法的门槛了，氪佬们也觉得太过于卑鄙。
# <br/><br/>
#   毕竟，《天际线》这游戏的发酵到目前口碑还是不错的。
# <br/><br/>
#   有人肯做好游戏，这点无论是平民还是氪佬都不会有非议。
# <br/><br/>
#   “……跑了。”刻竣顿时磕磕绊绊，辩解似得伸手比比划划，顾左右而言他：“但……跑了……不代表我没钓到过啊。”
# <br/><br/>
#   刻晋知道。
# <br/><br/>
#   好在结果是喜人的。
#   <div class="contentadv"><script>loadAdv(7,3);</script></div>
#   上架第一周的流水。
# <br/><br/>
#   但很快，这个方法也败下阵来。
# <br/><br/>
#   虽然肯定不及直接开放充值界面赚的多，但也算是浅浅弥补了一下这游戏目前的0收益。
# <br/><br/>
#   “那就上饿扁了点一条送过来！”刻竣悲愤道。
# <br/><br/>
#   一看自己老婆要生气，刻竣急忙轻咳一声，不打算触其霉头，一边端起茶水轻抿，一边把话茬抛给了刻雨：“小雨，你想去哪里？”
# <br/><br/>
#   B计划失败，C计划就会跟着失败。
# <br/><br/>
#   在临时创建的圣战小组里面，有懂行的专业人士在尝试了几番之后，把失败的截图发到群里。
# <br/><br/>
#   虽然说，在蓝星上游戏法跟常规的民法刑法不同，它更像是一个维护市场环境的东西，更类似于校规，公司规定这类，没有绝对的权威性，由蓝星特设的部门游戏监管局把控。
# <br/><br/>
#   “你这不还是吃。”刻竣很无奈的扶了扶眼镜，明显不太能理解女人的脑回路。
# <br/><br/>
#   同时也侧面检验了自己这一波计划的无懈可击。
# <br/><br/>
#   动用了最后一种方法。
# <br/><br/>
#   作为集家中千万宠爱于一身的小公主。
# <br/><br/>
#   转而开始跟家里人商量着，下周末去哪里给刻雨办个生日。
# <br/><br/>
#   但他也在暗中观察。
# <br/><br/>
#   “优惠什么优惠，你女儿今年18岁，人生有几个18岁？光想着你那点优惠了，用现在互联网上流行的话说，你就是个直男。”刻母作为母亲也作为女人，属于浪漫主义者，一听见刻竣的提议立刻否决。
# <br/><br/>
#   就是尝试写一个拦截广告的插件。
# <br/><br/>
#   气急败坏的氪佬小团体直接破罐子破摔。
# <br/><br/>
#   当着孩子面呢，被这样戳脊梁骨，这换谁谁受得了？
# <br/><br/>
#   生怕这帮小崽子真给自己创翻了车。
# <br/><br/>
#   “这……”一群氪佬们望着截图，面面相觑。
# <br/><br/>
# 涓�涓冧簩.涓�闆堕浂.涔濅節.涓�鍏�浜�
# <br/><br/>
#   “即便屏蔽了广告，但灰框还在这里，一样遮挡住了充值界面，这个只能从他自己的程序里面改。”
# <br/><br/>
#   然后便是低声碎碎念着旁人听不懂的话，什么‘窝打少了’、‘杆子小了’、‘鱼苗太幼’、‘人也老了’
# <br/><br/>
#   他其实每天都在高强度吃自己的瓜。
# <br/><br/>
#   什么‘头号战犯刻晋出列！’，什么‘氪佬小团体的圣战操办仪式’，‘氪佬小团体圣战大失败’之类，他都看在眼里。
# <br/><br/>
#   广告费的收益倒是赚了都快有10万了。
# <br/><br/>
#   此时一家人都聚在餐桌前，东一句西一句的规划。
# <br/><br/>
#   按照这个节奏下去。
# <br/><br/>
#   可以说氪佬小团体功不可没了。
# <br/><br/>
#   但最终均无一例外失败。
# <br/><br/>
#   “行，我也不跟你争。你就说，万一没钓上来怎么办？总不能让小雨过生日那天饿着肚子吧？”刻母又道。
# <br/><br/>
#   “那家伙写程序的时候，直接把广告框跟充值界面给焊死了，两者是双位一体的。”
# <br/><br/>
#   暂时没有发言权的刻晋跟刻雨，两个人扭头望向自己老爹。
# <br/><br/>
#   刻小姐即将在这周末，也就是6天后，迎来她18岁的成人礼生日。
# <br/><br/>
#   作为一款偏小众并且还没进入主流视野的单机游戏，能在上架后的一周内，热度不降反增，让更多的路人知道了【头号玩家】这么一个公司，也知道了刻晋这么一位设计师。
# <br/><br/>
#   “因为《天际线》不让充钱也没有战力排行榜，所以他们战斗力为0，所以摆不平也正常，合理！”
# <br/><br/>
#   网友们的吃瓜调侃，甚至让《天际线》这款游戏的热度又小窜了一截。
# <br/><br/>
#   但在游戏行业内也属于人人都要遵守的，不然被扼令下架整改，谁也遭不住。
# <br/><br/>
#   凭一款影响力并不太大的游戏，就想让游戏法改动，属实是痴人说梦了。
# <br/><br/>
#   最终权衡一下，选择放弃。
# <br/><br/>
#   ‘上饿扁了点一条’这种话，可能是作为一名钓鱼佬最大程度的让步了。
# <br/><br/>
#   “噗！！！”刻竣一口茶水全喷地上了。
# <br/><br/>
#   上来就被对面设计师啪啪几巴掌给扇的晕头转向的氪佬们，在接下来的两天内又冥思苦想了许多旁门偏方。
# <br/><br/>
#   这款游戏的最终收益也必然是0！
# <br/><br/>
#   胜券在握，无需担忧。把心放进肚子里，坐等终极奖励到手的刻晋，不再关注网上的消息。
# <br/><br/>
#   时时刻刻紧盯着。
# <br/><br/>
#   “那去哪？”刻母不悦道。
# <br/><br/>
#   最后的结果就是，发到监管局那边，对面连甩都没甩这帮人。
# <br/><br/>
#   举报大法！
# <br/><br/>
#   plan B失败。
# <br/><br/>
#   “要不就上小李那酒店摆上一桌，报我名字能优惠。”小李是刻竣早年教的一个学生，靠着家里关系在江林本地开了一家四星级酒店，偶尔还会与刻竣保持联系。
# <br/><br/>
#   “大佬们加油啊！这种破坏市场的家伙就该严惩！再加大点力度！/狗头”
# <br/><br/>
#   这一招不但没有成功，反而还让一众吃瓜网友看了笑话。
# <br/><br/>
#   “要我说，还是定一家高档的西式餐厅，好好给女儿过一次像样的生日。”
# <br/><br/>
#   打开游戏的同时运行插件，就能完美屏蔽广告，把充值界面狠狠地在大庭广众之下暴露出来！<br/>
#   然后用大钞票把它灌满塞晕！
# <br/><br/>
#   然后接着，讨论出的第二个方法。
# <br/><br/>
#   联名上书写了封电子邮件，痛斥《天际线》可能会带来的游戏恶果。
# <br/><br/>
#   0！
# <br/><br/>
#   刻晋与刻雨又扭头望向老妈。
# <br/><br/>
#   氪佬们集中抗议的，主要还是针对这个过于离谱的充值界面，有可能会产生不可控的影响。
# <br/><br/>
#   刻母也没忍住笑：“那我们怕是得饿上一整天。”
# <br/><br/>
#   刻晋作为家中纸面实力上，话语权最低的那一个，整场讨论光在嗑瓜子，由始至终没有开口。
# <br/><br/>
#   而最近一周发生的一切，刻晋并非没有耳闻。
# <br/><br/>
#   反正刻竣受不了，他瞬间就红温了，但不敢高声语，恐惊心上人。
# <br/><br/>
#   整个家中都充满了快活的气息。
# <br/><br/>
#   “这个氪佬小群体几个人的战力排行榜加起来都是以亿计算的，怎么连个《天际线》都摆不平啊/坏笑/坏笑”
# <br/><br/>
#   邮件的大概内容是：‘建议修改游戏法，以免《天际线》这类的游戏厂商趁机钻空子，从而严重扰乱市场环境！’
# <br/><br/>
#   而准备的第三手计划断网大法也自然而然失败。
# <br/><br/>
#   “那鱼呢？”刻母问。
# <br/><br/>
#   尽管赔上了一款游戏的收益，但后续能解锁的可是足以建立一栋游戏帝国的IP，怎么算都不亏。
# <br/><br/>
#   “我？我都行啊……”刻雨偏着头想了想，然后绽放出了一道甜甜的笑容：“只要能跟一家人在一起开开心心，其他的都无所谓啦。要不就跟着老爸去钓鱼吧，然后咱们全家就在河边弄一个露天的BBQ，全鱼宴！老爸钓多少上来我们就吃多少！嘻~”
# <br/><br/>
#   只能用力的攥着茶杯，额头上的青筋条条绽出，连连用手指跺着桌面：“看不起谁呢？之前20斤！你懂不懂20斤是什么概念！这么大！”
# <br/><br/>
#   从老爹那紧皱的眉头，与咬牙切齿的表情中。
# <br/><br/>
#   跟B计划一样，其实都是采用了试图将广告跟充值界面分离的行为。
# <br/><br/>
#   　感谢‘玄天子’大佬的999书币！
# <br/><br/>
#   　　感谢大佬支持！
# <br/><br/>
#   　　砰砰砰！！！<br/>
#   　　<br/>
#   　<br/>
#   (本章完)
# <br/><br/>
# <div class="bottom-ad">
# <script>loadAdv(3, 0);</script>
# </div>
# </div>
# <div class="page1">
# <a href="https://www.69shu.pro/txt/53686/34787586">上一章</a>
# <a href="javascript:;" id="a_addbookcase" onclick="addbookcase(53686,34787587);" rel="nofollow">书签</a>
# <a href="https://www.69shu.pro/book/53686/" title="只想让玩家省钱的我却被氪成首富最新章节列表">目录</a>
# <a href="https://www.69shu.pro/txt/53686/34787588">下一章</a>
# </div>
# <div class="bottom-ad2">
# <script>loadAdv(3, 2);</script>
# </div>
# <div class="baocuo" id="baocuo"></div>
# </div>
# <div class="tuijian" id="tuijian"></div>
# </div>
# <div class="setbox">
# <div class="setli">
# <a class="setclose" href="javascript:;">关闭</a>
# <ul>
# <li>
# <label>背景</label>
# <div class="setbg">
# <a href="javascript:;" onclick="setnavbg(0)"></a>
# <a href="javascript:;" onclick="setnavbg(1)"></a>
# <a href="javascript:;" onclick="setnavbg(2)"></a>
# <a href="javascript:;" onclick="setnavbg(3)"></a>
# <a href="javascript:;" onclick="setnavbg(4)"></a>
# </div>
# </li>
# <li><label>字体</label>
# <div class="setfontf">
# <a href="javascript:;" onclick="setfont(0)">雅黑</a>
# <a href="javascript:;" onclick="setfont(1)">苹方</a>
# <a href="javascript:;" onclick="setfont(2)">等线</a>
# </div>
# </li>
# <li><label>字号</label>
# <div class="setfontsize">
# <input class="sizenum" readonly="" type="text" value="22"/>
# <a class="cut" href="javascript:;" onclick="fontcut()">-</a>
# <a class="add" href="javascript:;" onclick="fontadd()">+</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div id="pagefootermenu"></div>
# <div class="modelbg"></div>
# <script src="https://cdn.shucdn.com/js/jquery.min.js"></script>
# <script src="https://cdn.shucdn.com/js/202403/newmenu.js?v=202403"></script>
# <script src="https://cdn.shucdn.com/js/chinese.js"></script>
# <script src="https://cdn.shucdn.com/js/202403/newread.js?v=202403"></script>
# <script>Tools();</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-WZ8MZNNPQR"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#
#     function gtag() {
#         dataLayer.push(arguments);
#     }
#
#     gtag('js', new Date());
#     gtag('config', 'G-WZ8MZNNPQR');
# </script>
# <script type="text/javascript">
# document.cookie = "history_val=1711000183@6d3d316f61ed797a2bda830ed80bd1fe; path=/; max-age=3600;";
# </script>
# </body>
# </html>

# %%
text = soup.find(class_="txtnav")
text = cleanup(text)
text = remove_before_second_occurrence(text, "\u2003\u2003")
text
# Out:
# '\u2003\u2003第43章 游戏首周流水出炉！\n\n\r\n\u2003\u2003氪佬们最开始想的办法，是想找一个比较高明的黑客，入侵一下头号玩家公司的后台端口，然后改写充值界面的程序，直接从根源解决问题。\n\n\r\n\u2003\u2003不过由于这种行为已经足够触碰到违法的门槛了，氪佬们也觉得太过于卑鄙。\n\n\r\n\u2003\u2003毕竟，《天际线》这游戏的发酵到目前口碑还是不错的。\n\n\r\n\u2003\u2003有人肯做好游戏，这点无论是平民还是氪佬都不会有非议。\n\n\r\n\u2003\u2003“……跑了。”刻竣顿时磕磕绊绊，辩解似得伸手比比划划，顾左右而言他：“但……跑了……不代表我没钓到过啊。”\n\n\r\n\u2003\u2003刻晋知道。\n\n\r\n\u2003\u2003好在结果是喜人的。\n\u2003\u2003\n\r\n\u2003\u2003上架第一周的流水。\n\n\r\n\u2003\u2003但很快，这个方法也败下阵来。\n\n\r\n\u2003\u2003虽然肯定不及直接开放充值界面赚的多，但也算是浅浅弥补了一下这游戏目前的0收益。\n\n\r\n\u2003\u2003“那就上饿扁了点一条送过来！”刻竣悲愤道。\n\n\r\n\u2003\u2003一看自己老婆要生气，刻竣急忙轻咳一声，不打算触其霉头，一边端起茶水轻抿，一边把话茬抛给了刻雨：“小雨，你想去哪里？”\n\n\r\n\u2003\u2003B计划失败，C计划就会跟着失败。\n\n\r\n\u2003\u2003在临时创建的圣战小组里面，有懂行的专业人士在尝试了几番之后，把失败的截图发到群里。\n\n\r\n\u2003\u2003虽然说，在蓝星上游戏法跟常规的民法刑法不同，它更像是一个维护市场环境的东西，更类似于校规，公司规定这类，没有绝对的权威性，由蓝星特设的部门游戏监管局把控。\n\n\r\n\u2003\u2003“你这不还是吃。”刻竣很无奈的扶了扶眼镜，明显不太能理解女人的脑回路。\n\n\r\n\u2003\u2003同时也侧面检验了自己这一波计划的无懈可击。\n\n\r\n\u2003\u2003动用了最后一种方法。\n\n\r\n\u2003\u2003作为集家中千万宠爱于一身的小公主。\n\n\r\n\u2003\u2003转而开始跟家里人商量着，下周末去哪里给刻雨办个生日。\n\n\r\n\u2003\u2003但他也在暗中观察。\n\n\r\n\u2003\u2003“优惠什么优惠，你女儿今年18岁，人生有几个18岁？光想着你那点优惠了，用现在互联网上流行的话说，你就是个直男。”刻母作为母亲也作为女人，属于浪漫主义者，一听见刻竣的提议立刻否决。\n\n\r\n\u2003\u2003就是尝试写一个拦截广告的插件。\n\n\r\n\u2003\u2003气急败坏的氪佬小团体直接破罐子破摔。\n\n\r\n\u2003\u2003当着孩子面呢，被这样戳脊梁骨，这换谁谁受得了？\n\n\r\n\u2003\u2003生怕这帮小崽子真给自己创翻了车。\n\n\r\n\u2003\u2003“这……”一群氪佬们望着截图，面面相觑。\n\n\n涓�涓冧簩.涓�闆堕浂.涔濅節.涓�鍏�浜�\n\n\r\n\u2003\u2003“即便屏蔽了广告，但灰框还在这里，一样遮挡住了充值界面，这个只能从他自己的程序里面改。”\n\n\r\n\u2003\u2003然后便是低声碎碎念着旁人听不懂的话，什么‘窝打少了’、‘杆子小了’、‘鱼苗太幼’、‘人也老了’\n\n\r\n\u2003\u2003他其实每天都在高强度吃自己的瓜。\n\n\r\n\u2003\u2003什么‘头号战犯刻晋出列！’，什么‘氪佬小团体的圣战操办仪式’，‘氪佬小团体圣战大失败’之类，他都看在眼里。\n\n\r\n\u2003\u2003广告费的收益倒是赚了都快有10万了。\n\n\r\n\u2003\u2003此时一家人都聚在餐桌前，东一句西一句的规划。\n\n\r\n\u2003\u2003按照这个节奏下去。\n\n\r\n\u2003\u2003可以说氪佬小团体功不可没了。\n\n\r\n\u2003\u2003但最终均无一例外失败。\n\n\r\n\u2003\u2003“行，我也不跟你争。你就说，万一没钓上来怎么办？总不能让小雨过生日那天饿着肚子吧？”刻母又道。\n\n\r\n\u2003\u2003“那家伙写程序的时候，直接把广告框跟充值界面给焊死了，两者是双位一体的。”\n\n\r\n\u2003\u2003暂时没有发言权的刻晋跟刻雨，两个人扭头望向自己老爹。\n\n\r\n\u2003\u2003刻小姐即将在这周末，也就是6天后，迎来她18岁的成人礼生日。\n\n\r\n\u2003\u2003作为一款偏小众并且还没进入主流视野的单机游戏，能在上架后的一周内，热度不降反增，让更多的路人知道了【头号玩家】这么一个公司，也知道了刻晋这么一位设计师。\n\n\r\n\u2003\u2003“因为《天际线》不让充钱也没有战力排行榜，所以他们战斗力为0，所以摆不平也正常，合理！”\n\n\r\n\u2003\u2003网友们的吃瓜调侃，甚至让《天际线》这款游戏的热度又小窜了一截。\n\n\r\n\u2003\u2003但在游戏行业内也属于人人都要遵守的，不然被扼令下架整改，谁也遭不住。\n\n\r\n\u2003\u2003凭一款影响力并不太大的游戏，就想让游戏法改动，属实是痴人说梦了。\n\n\r\n\u2003\u2003最终权衡一下，选择放弃。\n\n\r\n\u2003\u2003‘上饿扁了点一条’这种话，可能是作为一名钓鱼佬最大程度的让步了。\n\n\r\n\u2003\u2003“噗！！！”刻竣一口茶水全喷地上了。\n\n\r\n\u2003\u2003上来就被对面设计师啪啪几巴掌给扇的晕头转向的氪佬们，在接下来的两天内又冥思苦想了许多旁门偏方。\n\n\r\n\u2003\u2003这款游戏的最终收益也必然是0！\n\n\r\n\u2003\u2003胜券在握，无需担忧。把心放进肚子里，坐等终极奖励到手的刻晋，不再关注网上的消息。\n\n\r\n\u2003\u2003时时刻刻紧盯着。\n\n\r\n\u2003\u2003“那去哪？”刻母不悦道。\n\n\r\n\u2003\u2003最后的结果就是，发到监管局那边，对面连甩都没甩这帮人。\n\n\r\n\u2003\u2003举报大法！\n\n\r\n\u2003\u2003plan B失败。\n\n\r\n\u2003\u2003“要不就上小李那酒店摆上一桌，报我名字能优惠。”小李是刻竣早年教的一个学生，靠着家里关系在江林本地开了一家四星级酒店，偶尔还会与刻竣保持联系。\n\n\r\n\u2003\u2003“大佬们加油啊！这种破坏市场的家伙就该严惩！再加大点力度！/狗头”\n\n\r\n\u2003\u2003这一招不但没有成功，反而还让一众吃瓜网友看了笑话。\n\n\r\n\u2003\u2003“要我说，还是定一家高档的西式餐厅，好好给女儿过一次像样的生日。”\n\n\r\n\u2003\u2003打开游戏的同时运行插件，就能完美屏蔽广告，把充值界面狠狠地在大庭广众之下暴露出来！\n\r\n\u2003\u2003然后用大钞票把它灌满塞晕！\n\n\r\n\u2003\u2003然后接着，讨论出的第二个方法。\n\n\r\n\u2003\u2003联名上书写了封电子邮件，痛斥《天际线》可能会带来的游戏恶果。\n\n\r\n\u2003\u20030！\n\n\r\n\u2003\u2003刻晋与刻雨又扭头望向老妈。\n\n\r\n\u2003\u2003氪佬们集中抗议的，主要还是针对这个过于离谱的充值界面，有可能会产生不可控的影响。\n\n\r\n\u2003\u2003刻母也没忍住笑：“那我们怕是得饿上一整天。”\n\n\r\n\u2003\u2003刻晋作为家中纸面实力上，话语权最低的那一个，整场讨论光在嗑瓜子，由始至终没有开口。\n\n\r\n\u2003\u2003而最近一周发生的一切，刻晋并非没有耳闻。\n\n\r\n\u2003\u2003反正刻竣受不了，他瞬间就红温了，但不敢高声语，恐惊心上人。\n\n\r\n\u2003\u2003整个家中都充满了快活的气息。\n\n\r\n\u2003\u2003“这个氪佬小群体几个人的战力排行榜加起来都是以亿计算的，怎么连个《天际线》都摆不平啊/坏笑/坏笑”\n\n\r\n\u2003\u2003邮件的大概内容是：‘建议修改游戏法，以免《天际线》这类的游戏厂商趁机钻空子，从而严重扰乱市场环境！’\n\n\r\n\u2003\u2003而准备的第三手计划断网大法也自然而然失败。\n\n\r\n\u2003\u2003“那鱼呢？”刻母问。\n\n\r\n\u2003\u2003尽管赔上了一款游戏的收益，但后续能解锁的可是足以建立一栋游戏帝国的IP，怎么算都不亏。\n\n\r\n\u2003\u2003“我？我都行啊……”刻雨偏着头想了想，然后绽放出了一道甜甜的笑容：“只要能跟一家人在一起开开心心，其他的都无所谓啦。要不就跟着老爸去钓鱼吧，然后咱们全家就在河边弄一个露天的BBQ，全鱼宴！老爸钓多少上来我们就吃多少！嘻~”\n\n\r\n\u2003\u2003只能用力的攥着茶杯，额头上的青筋条条绽出，连连用 ...

# %%
with open("test"+".txt", "a", encoding='utf-8') as file:
    file.write(texts)

# %%
def remove_before_second_occurrence(text, substring):
    # Find the first occurrence of the substring
    first_occurrence = text.find(substring)
    if first_occurrence == -1:
        return "Substring not found."

    # Find the second occurrence of the substring
    #second_occurrence = text.find(substring, first_occurrence + 1)
    #if second_occurrence == -1:
        #return "Second occurrence not found."

    # Return the text from the second occurrence onwards
    return text[first_occurrence:]

# %%
remove_before_second_occurrence(texts, "\u2003\u2003\t\t第")
